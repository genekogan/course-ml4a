# %% [markdown]
# # Introducing Keras
#
# In the next cell, we introduce [Keras](http://keras.io/), a high-level library for machine learning which we will use for the rest of the class. Keras is built on top of [Tensorflow](https://tensorflow.org/), which is an open-source framework which impelments machine learning methodology, particularly that of deep neural networks, by optimizing the efficiency of the computation. We do not have to deal so much with the details of this. For our purposes, Tensorflow is also a very low-level library which is not necessarily accessible to the typical engineer. Keras solves this by creating a wrapper around Tensorflow, reducing the complexity of coding neural networks, and giving us a set of convenient functions which implement lots of reusable routines. Most importantly, Keras (via Tensorflow) efficiently implement backpropagation to train neural networks on the GPU. Effectively, you could say that Keras is to Tensorflow what [Processing](http://processing.org/) is to Java.
#
# To start, we will re-implement what we did in the last section, a neural network to classify the Iris dataset, but this time we will use Keras.
#
# Start by importing the relevant Keras libraries that we will be using, as well as matplotlib and numpy.

# %%
import os
os.environ['KERAS_BACKEND'] = 'tensorflow'

import matplotlib.pyplot as plt
import numpy as np
import random

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
# Out:
# /Users/gene/Library/Python/3.5/lib/python/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %% [markdown]
# Let's load the Iris dataset again.

# %%
from sklearn import datasets

iris = datasets.load_iris()

X = iris.data
y = iris.target

# %% [markdown]
# Let's plot the data to have a better look at it. Below we plot the flowers in the Iris dataset according to their sepal length and width, and we label them according to color.

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X[:,0], X[:,1], c=y)
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.title('Iris dataset')

# %% [markdown]
# In the last lesson, we manually trained a neural network to classify the Iris dataset. This time, let's use the Keras library instead. First we need to shuffle and pre-process the data. Pre-processing in this case is normalization of the data, as well as converting it to a properly-shaped numpy array.

# %%
# how many samples in the dataset and how many classes?
num_samples = len(y)
num_classes = 1+int(np.amax(y, axis=0))

# shuffle the dataset
shuffle_order = np.random.permutation(num_samples)
X = X[shuffle_order, :]
y = y[shuffle_order]

# normalize X to between 0 and 1 and make sure it's float32
X = X / np.amax(X, axis=0)
X = X.astype('float32')

print("shape of X", X.shape)
print("first 5 rows of X\n", X[0:5, :])
print("first 5 labels\n", y[0:5])
# Out:
# shape of X (150, 4)
# first 5 rows of X
#  [[0.87341774 0.70454544 0.73913044 0.92      ]
#  [0.7848101  0.65909094 0.6231884  0.52      ]
#  [0.5822785  0.77272725 0.20289855 0.12      ]
#  [0.70886075 0.6136364  0.6086956  0.52      ]
#  [0.84810126 0.70454544 0.6376812  0.56      ]]
# first 5 labels
#  [2 1 0 1 1]

# %% [markdown]
# We need to split the data into a training set and a test set. Let's take the first 30% of the dataset to use as a test set.
#
# TODO: why?

# %%
test_split = 0.3

n_test = int(test_split * num_samples)

x_train, x_test = X[n_test:, :], X[:n_test, :] 
y_train, y_test = y[n_test:], y[:n_test] 

print('%d training samples, %d test samples' % (x_train.shape[0], x_test.shape[0]))
# Out:
# 105 training samples, 45 test samples

# %% [markdown]
# Convert the labels into one-hot vectors. So if there are 3 classes, label 0 = [1, 0, 0], label 1 = [0, 1, 0], etc.

# %%
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

print("Training data shape: X", x_train.shape, " y", y_train.shape)
print("Test data shape: X", x_test.shape, " y", y_test.shape)
# Out:
# Training data shape: X (105, 4)  y (105, 3)
# Test data shape: X (45, 4)  y (45, 3)

# %% [markdown]
# In Keras, to instantiate a neural network model, we use the `Sequential` class. Sequential simply means a model with a sequence of layers which propagate in one direction, from input to output.

# %%
model = Sequential()

# %% [markdown]
# We now have an empty neural network called `model`. Now let's add our first layer, which will be our input layer. We will do this using Keras's `Dense` class which will instantiate our input layer.
#
# The reason why it is called "Dense" is that the layer is "fully-connected," which means that all of it's neurons are connected to all the neurons in the previous layer, with no empty connections. This may seem confusing at first because we have not yet seen neural network layers which are not fully-connected; we will see this in the next chapter when we introduce convolutional networks.
#
# To create a Dense layer, we have three arguments that need to be specified: the number of neurons, the activation function, and the

# %%
model.add(Dense(10, activation='sigmoid', input_dim=4))

# %% [markdown]
# TODO: make a graphic of the net architecture
#
# We can also get a readout of the current state of the network using `model.summary`:

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 10)                50
# =================================================================
# Total params: 50
# Trainable params: 50
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Let's add another layer of 20 neurons, also with sigmoid activation, and look at the summary of the graph now.

# %%
model.add(Dense(10, activation='sigmoid'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 10)                50
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                110
# =================================================================
# Total params: 160
# Trainable params: 160
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Finally, we will add the output layer, which will be a fully-connected (Dense) layer whose size is the number of classes, which in our case is 3, for the three different flower types.
#
# Notice that this time, instead of having the activation be a sigmoid as before, now we use the softmax activation, which is the most typical and recommended activation function for the output layer in a multi-class classification such as this.
#
# We add it, and look at the final summary.

# %%
model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 10)                50
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_21 (Dense)             (None, 3)                 33
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now we are finished specifying the architecture of the model. Now we need to specify our loss function and optimizer, and then compile the model. Let's discuss each of these things.
#
# We introduces loss functions in the last session, and we used the simple mean-squared error (MSE) loss function to evaluate the quality of our network. While MSE works nicely for regression, and can work for classification as well, it is generally not preferred for classification, because class variables are not naturally continuous and therefore, the MSE error, being a continuous value is not quite the right loss function. Instead, what scientists generally prefer for multi-class classification is categorical cross-entropy loss
#
#
# TODO: define cross-entropy
# https://ml-cheatsheet.readthedocs.io/en/latest/loss_functions.html
#
#
# Additionally, we must select an optimizer. The optimizer is the specific variant of gradient descent which will be used in training. These ...
#
# TODO: optimizers
#
# Finally, the model is compiled. Compiling means that Keras (actually Tensorflow internally) is allocating memory for a "computational graph" whose architecture is that which is specified by your model definition. This is done for optimization purposes, and a full understanding of how that's done is not necessary for this course and is beyond its scope.
#
# In compiling, we can also pass a set of metrics to keep track of during training. Since we are performing classification, the most useful one for now is just accuracy.

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='RMSProp',
              metrics=['accuracy'])

# %% [markdown]
# We are finally ready to train. In the next cell, we run the `fit` command which will begin the process of training. There are several important arguments to fit. The first is the training data and labels (`x_train` and `y_train`), as well as the validation set (`x_test` and `y_test`).
#
# Additionally, we must specify the `batch_size` which refers to the number of training samples to calculate the gradient over, as well as the number of `epochs`, which refers to the number of times we cycle through the training set. In general, more epochs are usually better, although in practice, the accuracy of the network may stop improving early, which makes it unnecessary to train too many epochs.
#
# TODO: validation set why?

# %%
history = model.fit(x_train, y_train,
                    batch_size=15,
                    epochs=100,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Train on 105 samples, validate on 45 samples
# Epoch 1/100
# 105/105 [==============================] - 0s 112us/step - loss: 0.9866 - acc: 0.6762 - val_loss: 1.0007 - val_acc: 0.6444
# Epoch 2/100
# 105/105 [==============================] - 0s 108us/step - loss: 0.9838 - acc: 0.6762 - val_loss: 0.9983 - val_acc: 0.6444
# Epoch 3/100
# 105/105 [==============================] - 0s 99us/step - loss: 0.9818 - acc: 0.6762 - val_loss: 0.9962 - val_acc: 0.6444
# Epoch 4/100
# 105/105 [==============================] - 0s 111us/step - loss: 0.9793 - acc: 0.6762 - val_loss: 0.9939 - val_acc: 0.6444
# Epoch 5/100
# 105/105 [==============================] - 0s 113us/step - loss: 0.9769 - acc: 0.6762 - val_loss: 0.9915 - val_acc: 0.6444
# Epoch 6/100
# 105/105 [==============================] - 0s 102us/step - loss: 0.9738 - acc: 0.6762 - val_loss: 0.9888 - val_acc: 0.6444
# Epoch 7/100
# 105/105 [==============================] - 0s 107us/step - loss: 0.9720 - acc: 0.6762 - val_loss: 0.9864 - val_acc: 0.6444
# Epoch 8/100
# 105/105 [==============================] - 0s 116us/step - loss: 0.9689 - acc: 0.6762 - val_loss: 0.9832 - val_acc: 0.6444
# Epoch 9/100
# 105/105 [==============================] - 0s 103us/step - loss: 0.9672 - acc: 0.6762 - val_loss: 0.9809 - val_acc: 0.6444
# Epoch 10/100
# 105/105 [==============================] - 0s 103us/step - loss: 0.9630 - acc: 0.6762 - val_loss: 0.9777 - val_acc: 0.6444
# Epoch 11/100
# 105/105 [==============================] - 0s 101us/step - loss: 0.9601 - acc: 0.6762 - val_loss: 0.9746 - val_acc: 0.6444
# Epoch 12/100
# 105/105 [==============================] - 0s 122us/step - loss: 0.9578 - acc: 0.6762 - val_loss: 0.9715 - val_acc: 0.6444
# Epoch 13/100
# 105/105 [==============================] - 0s 106us/step - loss: 0.9532 - acc: 0.6762 - val_loss: 0.9682 - val_acc: 0.6444
# Epoch 14/100
# 105/105 [==============================] - 0s 112us/step - loss: 0.9508 - acc: 0.6762 - val_loss: 0.9640 - val_acc: 0.6444
# Epoch 15/100
# 105/105 [==============================] - 0s 109us/step - loss: 0.9479 - acc: 0.6762 - val_loss: 0.9615 - val_acc: 0.6444
# Epoch 16/100
# 105/105 [==============================] - 0s 103us/step - loss: 0.9434 - acc: 0.6762 - val_loss: 0.9586 - val_acc: 0.6444
# Epoch 17/100
# 105/105 [==============================] - 0s 113us/step - loss: 0.9406 - acc: 0.6762 - val_loss: 0.9550 - val_acc: 0.6444
# Epoch 18/100
# 105/105 [==============================] - 0s 105us/step - loss: 0.9365 - acc: 0.6762 - val_loss: 0.9510 - val_acc: 0.6444
# Epoch 19/100
# 105/105 [==============================] - 0s 105us/step - loss: 0.9334 - acc: 0.6762 - val_loss: 0.9469 - val_acc: 0.6444
# Epoch 20/100
# 105/105 [==============================] - 0s 112us/step - loss: 0.9304 - acc: 0.6762 - val_loss: 0.9439 - val_acc: 0.6444
# Epoch 21/100
# 105/105 [==============================] - 0s 104us/step - loss: 0.9265 - acc: 0.6762 - val_loss: 0.9411 - val_acc: 0.6444
# Epoch 22/100
# 105/105 [==============================] - 0s 107us/step - loss: 0.9245 - acc: 0.6762 - val_loss: 0.9374 - val_acc: 0.6444
# Epoch 23/100
# 105/105 [==============================] - 0s 105us/step - loss: 0.9206 - acc: 0.6762 - val_loss: 0.9344 - val_acc: 0.6444
# Epoch 24/100
# 105/105 [==============================] - 0s 104us/step - loss: 0.9166 - acc: 0.6762 - val_loss: 0.9310 - val_acc: 0.6444
# Epoch 25/100
# 105/105 [==============================] - 0s 115us/step - loss: 0.9133 - acc: 0.6762 - val_loss: 0.9275 - val_acc: 0.6444
# Epoch 26/100
# 105/105 [==============================] - 0s 101us/step - loss: 0.9093 - acc: 0.6857 - val_loss: 0.9237 - val_acc: 0.6444
# Epoch 27/100
# 105/105 [==============================] - 0s 103us/step - loss: 0.9057 - acc: 0.6762 - val_loss: 0.9192 - val_acc: 0.6444
# Epoch 28/100
# 105/105 [==============================] - 0s 117us/step - loss: 0.9023 - acc: 0.6762 - val_loss: 0.9147 - val_acc: 0.6444
# Epoch 29/100
# 105/105 [==============================] - 0s 102us/step - loss: 0.8981 - acc: 0.6762 - val_loss: 0.9118 - val_acc: 0.6444
# Epoch 30/100
# 105/105 [==============================] - 0s 104us/step - loss: 0.8939 - acc: 0.6762 - val_loss: 0.9073 - val_acc: 0.6444
# Epoch 31/100
# 105/105 [==============================] - 0s 106us/step - loss: 0.8897 - acc: 0.6762 - val_loss: 0.9031 - val_acc: 0.6444
# Epoch 32/100
# 105/105 [==============================] - 0s 116us/step - loss: 0.8861 - acc: 0.6762 - val_loss: 0.8987 - val_acc: 0.6444
# Epoch 33/100
# 105/105 [==============================] - 0s 106us/step - loss: 0.8824 - acc: 0.6762 - val_loss: 0.8950 - val_acc: 0.6444
# Epoch 34/100
# 105/105 [==============================] - 0s 105us/step - loss: 0.8771 - acc: 0.6762 - val_loss: 0.8910 - val_acc: 0.6444
# Epoch 35/100
# 105/105 [==============================] - 0s 107us/step - loss: 0.8744 - acc: 0.6762 - val_loss: 0.8866 - val_acc: 0.6444
# Epoch 36/100
# 105/105 [==============================] - 0s 114us/step - loss: 0.8696 - acc: 0.6762 - val_loss: 0.8822 - val_acc: 0.6444
# Epoch 37/100
# 105/105 [==============================] - 0s 111us/step - loss: 0.8657 - acc: 0.6857 - val_loss: 0.8778 - val_acc: 0.6444
# Epoch 38/100
# 105/105 [==============================] - 0s 111us/step - loss: 0.8608 - acc: 0.6857 - val_loss: 0.8731 - val_acc: 0.6444
# Epoch 39/100
# 105/105 [==============================] - 0s 107us/step - loss: 0.8568 - acc: 0.7143 - val_loss: 0.8691 - val_acc: 0.6444
# Epoch 40/100
# 105/105 [==============================] - 0s 116us/step - loss: 0.8521 - acc: 0.6762 - val_loss: 0.8638 - val_acc: 0.6444
# Epoch 41/100
# 105/105 [==============================] - 0s 111us/step - loss: 0.8477 - acc: 0.6952 - val_loss: 0.8592 - val_acc: 0.6444
# Epoch 42/100
# 105/105 [==============================] - 0s 141us/step - loss: 0.8421 - acc: 0.7048 - val_loss: 0.8541 - val_acc: 0.6444
# Epoch 43/100
# 105/105 [==============================] - 0s 116us/step - loss: 0.8379 - acc: 0.6857 - val_loss: 0.8493 - val_acc: 0.6444
# Epoch 44/100
# 105/105 [==============================] - 0s 111us/step - loss: 0.8329 - acc: 0.7048 - val_loss: 0.8445 - val_acc: 0.6444
# Epoch 45/100
# 105/105 [==============================] - 0s 111us/step - loss: 0.8281 - acc: 0.7143 - val_loss: 0.8404 - val_acc: 0.6444
# Epoch 46/100
# 105/105 [==============================] - 0s 116us/step - loss: 0.8243 - acc: 0.7143 - val_loss: 0.8359 - val_acc: 0.6444
# Epoch 47/100
# 105/105 [==============================] - 0s 122us/step - loss: 0.8190 - acc: 0.6952 - val_loss: 0.8308 - val_acc: 0.6444
# Epoch 48/100
# 105/105 [==============================] - 0s 105us/step - loss: 0.8141 - acc: 0.7048 - val_loss: 0.8256 - val_acc: 0.6444
# Epoch 49/100
# 105/105 [==============================] - 0s 104us/step - loss: 0.8094 - acc: 0.7143 - val_loss: 0.8205 - val_acc: 0.6444
# Epoch 50/100
# 105/105 [==============================] - 0s 114us/step - loss: 0.8052 - acc: 0.7143 - val_loss: 0.8155 - val_acc: 0.6667
# Epoch 51/100
# 105/105 [==============================] - 0s 108us/step - loss: 0.7996 - acc: 0.7143 - val_loss: 0.8100 - val_acc: 0.6667
# Epoch 52/100
# 105/105 [==============================] - 0s 106us/step - loss: 0.7949 - acc: 0.7143 - val_loss: 0.8049 - val_acc: 0.6667
# Epoch 53/100
# 105/105 [==============================] - 0s 110us/step - loss: 0.7907 - acc: 0.7143 - val_loss: 0.8000 - val_acc: 0.6667
# Epoch 54/100
# 105/105 [==============================] - 0s 110us/step - loss: 0.7853 - acc: 0.7238 - val_loss: 0.7951 - val_acc: 0.6667
# Epoch 55/100
# 105/105 [==============================] - 0s 108us/step - loss: 0.7811 - acc: 0.7238 - val_loss: 0.7904 - val_acc: 0.6667
# Epoch 56/100
# 105/105 [==============================] - 0s 102us/step - loss: 0.7760 - acc: 0.7238 - val_loss: 0.7860 - val_acc: 0.6667
# Epoch 57/100
# 105/105 [==============================] - 0s 139us/step - loss: 0.7722 - acc: 0.7143 - val_loss: 0.7808 - val_acc: 0.6667
# Epoch 58/100
# 105/105 [==============================] - 0s 129us/step - loss: 0.7667 - acc: 0.7429 - val_loss: 0.7760 - val_acc: 0.6667
# Epoch 59/100
# 105/105 [==============================] - 0s 116us/step - loss: 0.7615 - acc: 0.7238 - val_loss: 0.7714 - val_acc: 0.6667
# Epoch 60/100
# 105/105 [==============================] - 0s 105us/step - loss: 0.7575 - acc: 0.7238 - val_loss: 0.7661 - val_acc: 0.6667
# Epoch 61/100
# 105/105 [==============================] - 0s 103us/step - loss: 0.7520 - acc: 0.7238 - val_loss: 0.7605 - val_acc: 0.6667
# Epoch 62/100
# 105/105 [==============================] - 0s 119us/step - loss: 0.7473 - acc: 0.7238 - val_loss: 0.7551 - val_acc: 0.6667
# Epoch 63/100
# 105/105 [==============================] - 0s 104us/step - loss: 0.7429 - acc: 0.7238 - val_loss: 0.7504 - val_acc: 0.6667
# Epoch 64/100
# 105/105 [==============================] - 0s 106us/step - loss: 0.7373 - acc: 0.7333 - val_loss: 0.7454 - val_acc: 0.6667
# Epoch 65/100
# 105/105 [==============================] - 0s 104us/step - loss: 0.7333 - acc: 0.7333 - val_loss: 0.7400 - val_acc: 0.6889
# Epoch 66/100
# 105/105 [==============================] - 0s 106us/step - loss: 0.7282 - acc: 0.7429 - val_loss: 0.7354 - val_acc: 0.6667
# Epoch 67/100
# 105/105 [==============================] - 0s 109us/step - loss: 0.7231 - acc: 0.7524 - val_loss: 0.7300 - val_acc: 0.6889
# Epoch 68/100
# 105/105 [==============================] - 0s 107us/step - loss: 0.7182 - acc: 0.7429 - val_loss: 0.7245 - val_acc: 0.6889
# Epoch 69/100
# 105/105 [==============================] - 0s 115us/step - loss: 0.7127 - acc: 0.7524 - val_loss: 0.7192 - val_acc: 0.6889
# Epoch 70/100
# 105/105 [==============================] - 0s 109us/step - loss: 0.7083 - acc: 0.7429 - val_loss: 0.7139 - val_acc: 0.6889
# Epoch 71/100
# 105/105 [==============================] - 0s 105us/step - loss: 0.7034 - acc: 0.7429 - val_loss: 0.7086 - val_acc: 0.6889
# Epoch 72/100
# 105/105 [==============================] - 0s 125us/step - loss: 0.6968 - acc: 0.7619 - val_loss: 0.7031 - val_acc: 0.6889
# Epoch 73/100
# 105/105 [==============================] - 0s 113us/step - loss: 0.6913 - acc: 0.7524 - val_loss: 0.6967 - val_acc: 0.6889
# Epoch 74/100
# 105/105 [==============================] - 0s 116us/step - loss: 0.6859 - acc: 0.7810 - val_loss: 0.6910 - val_acc: 0.6889
# Epoch 75/100
# 105/105 [==============================] - 0s 103us/step - loss: 0.6815 - acc: 0.7619 - val_loss: 0.6857 - val_acc: 0.6889
# Epoch 76/100
# 105/105 [==============================] - 0s 111us/step - loss: 0.6759 - acc: 0.7810 - val_loss: 0.6810 - val_acc: 0.6889
# Epoch 77/100
# 105/105 [==============================] - 0s 109us/step - loss: 0.6719 - acc: 0.7619 - val_loss: 0.6762 - val_acc: 0.6889
# Epoch 78/100
# 105/105 [==============================] - 0s 108us/step - loss: 0.6665 - acc: 0.7619 - val_loss: 0.6705 - val_acc: 0.6889
# Epoch 79/100
# 105/105 [==============================] - 0s 123us/step - loss: 0.6619 - acc: 0.7619 - val_loss: 0.6651 - val_acc: 0.6889
# Epoch 80/100
# 105/105 [==============================] - 0s 127us/step - loss: 0.6575 - acc: 0.7714 - val_loss: 0.6604 - val_acc: 0.6889
# Epoch 81/100
# 105/105 [==============================] - 0s 103us/step - loss: 0.6532 - acc: 0.7714 - val_loss: 0.6558 - val_acc: 0.6889
# Epoch 82/100
# 105/105 [==============================] - 0s 105us/step - loss: 0.6479 - acc: 0.7810 - val_loss: 0.6506 - val_acc: 0.7111
# Epoch 83/100
# 105/105 [==============================] - 0s 109us/step - loss: 0.6432 - acc: 0.7810 - val_loss: 0.6456 - val_acc: 0.7111
# Epoch 84/100
# 105/105 [==============================] - 0s 111us/step - loss: 0.6383 - acc: 0.7810 - val_loss: 0.6401 - val_acc: 0.7111
# Epoch 85/100
# 105/105 [==============================] - 0s 108us/step - loss: 0.6338 - acc: 0.7810 - val_loss: 0.6347 - val_acc: 0.7111
# Epoch 86/100
# 105/105 [==============================] - 0s 112us/step - loss: 0.6284 - acc: 0.7810 - val_loss: 0.6294 - val_acc: 0.7111
# Epoch 87/100
# 105/105 [==============================] - 0s 103us/step - loss: 0.6237 - acc: 0.7810 - val_loss: 0.6239 - val_acc: 0.7111
# Epoch 88/100
# 105/105 [==============================] - 0s 106us/step - loss: 0.6187 - acc: 0.8000 - val_loss: 0.6193 - val_acc: 0.7111
# Epoch 89/100
# 105/105 [==============================] - 0s 109us/step - loss: 0.6141 - acc: 0.7810 - val_loss: 0.6137 - val_acc: 0.7111
# Epoch 90/100
# 105/105 [==============================] - 0s 108us/step - loss: 0.6088 - acc: 0.8000 - val_loss: 0.6082 - val_acc: 0.7111
# Epoch 91/100
# 105/105 [==============================] - 0s 109us/step - loss: 0.6049 - acc: 0.7810 - val_loss: 0.6034 - val_acc: 0.7111
# Epoch 92/100
# 105/105 [==============================] - 0s 112us/step - loss: 0.5999 - acc: 0.8000 - val_loss: 0.5983 - val_acc: 0.7333
# Epoch 93/100
# 105/105 [==============================] - 0s 103us/step - loss: 0.5964 - acc: 0.8000 - val_loss: 0.5930 - val_acc: 0.7778
# Epoch 94/100
# 105/105 [==============================] - 0s 106us/step - loss: 0.5905 - acc: 0.8286 - val_loss: 0.5888 - val_acc: 0.7778
# Epoch 95/100
# 105/105 [==============================] - 0s 108us/step - loss: 0.5867 - acc: 0.8000 - val_loss: 0.5835 - val_acc: 0.7778
# Epoch 96/100
# 105/105 [==============================] - 0s 100us/step - loss: 0.5818 - acc: 0.8095 - val_loss: 0.5782 - val_acc: 0.8444
# Epoch 97/100
# 105/105 [==============================] - 0s 100us/step - loss: 0.5776 - acc: 0.8286 - val_loss: 0.5732 - val_acc: 0.8444
# Epoch 98/100
# 105/105 [==============================] - 0s 107us/step - loss: 0.5739 - acc: 0.8381 - val_loss: 0.5684 - val_acc: 0.8444
# Epoch 99/100
# 105/105 [==============================] - 0s 104us/step - loss: 0.5690 - acc: 0.8190 - val_loss: 0.5636 - val_acc: 0.8444
# Epoch 100/100
# 105/105 [==============================] - 0s 102us/step - loss: 0.5644 - acc: 0.8286 - val_loss: 0.5589 - val_acc: 0.8444

# %% [markdown]
# As you can see above, we see ___
#
# We can evaluate the training set one last time at the end.

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.5589304778310987
# Test accuracy: 0.8444444470935397

# %% [markdown]
# We can also predict the value of a single unknown example or a set of them in th following way:

# %%
x_sample = x_test[0].reshape(1,4)
y_prob = model.predict(x_sample)[0]
y_pred = y_prob.argmax()
y_actual = y_test[0].argmax()

print("probabilities: ", y_prob)
print("predicted = %d, actual = %d" % (y_pred, y_actual))
# Out:
# probabilities:  [0.04458046 0.32502648 0.630393  ]
# predicted = 2, actual = 2

# %% [markdown]
# Let's now train another neural network, but use a more complicated dataset; that of MNIST. MNIST is a dataset of handwritten digits

# %%
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
num_classes = 10

# %% [markdown]
# Let's see what the data is packaged like:

# %%
print('%d train samples, %d test samples'%(x_train.shape[0], x_test.shape[0]))
print("training data shape: ", x_train.shape, y_train.shape)
print("test data shape: ", x_test.shape, y_test.shape)
# Out:
# 60000 train samples, 10000 test samples
# training data shape:  (60000, 28, 28) (60000,)
# test data shape:  (10000, 28, 28) (10000,)

# %%
samples = np.concatenate([np.concatenate([x_train[i] for i in [int(random.random() * len(x_train)) for i in range(16)]], axis=1) for i in range(4)], axis=0)
plt.figure(figsize=(16,4))
plt.imshow(samples, cmap='gray')

# %%
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# Now let's make a
#
# TODO: relu activation

# %%
model = Sequential()
model.add(Dense(256, activation='sigmoid', input_dim=784))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             (None, 256)               200960
# _________________________________________________________________
# dense_23 (Dense)             (None, 100)               25700
# _________________________________________________________________
# dense_24 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 227,670
# Trainable params: 227,670
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='RMSProp',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
          batch_size=100,
          epochs=20,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.5180 - acc: 0.8662 - val_loss: 0.2466 - val_acc: 0.9255
# Epoch 2/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.2155 - acc: 0.9356 - val_loss: 0.1809 - val_acc: 0.9451
# Epoch 3/20
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.1601 - acc: 0.9518 - val_loss: 0.1428 - val_acc: 0.9569
# Epoch 4/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.1245 - acc: 0.9628 - val_loss: 0.1174 - val_acc: 0.9636
# Epoch 5/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.1004 - acc: 0.9702 - val_loss: 0.1019 - val_acc: 0.9689
# Epoch 6/20
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0833 - acc: 0.9753 - val_loss: 0.0884 - val_acc: 0.9720
# Epoch 7/20
# 60000/60000 [==============================] - 4s 71us/step - loss: 0.0702 - acc: 0.9791 - val_loss: 0.0812 - val_acc: 0.9735
# Epoch 8/20
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.0599 - acc: 0.9816 - val_loss: 0.0778 - val_acc: 0.9749
# Epoch 9/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0510 - acc: 0.9841 - val_loss: 0.0761 - val_acc: 0.9766
# Epoch 10/20
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.0443 - acc: 0.9864 - val_loss: 0.0703 - val_acc: 0.9776
# Epoch 11/20
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0379 - acc: 0.9884 - val_loss: 0.0698 - val_acc: 0.9774
# Epoch 12/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0328 - acc: 0.9903 - val_loss: 0.0732 - val_acc: 0.9775
# Epoch 13/20
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0283 - acc: 0.9915 - val_loss: 0.0666 - val_acc: 0.9790
# Epoch 14/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0243 - acc: 0.9933 - val_loss: 0.0657 - val_acc: 0.9805
# Epoch 15/20
# 60000/60000 [==============================] - 6s 99us/step - loss: 0.0212 - acc: 0.9940 - val_loss: 0.0653 - val_acc: 0.9814
# Epoch 16/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0185 - acc: 0.9952 - val_loss: 0.0679 - val_acc: 0.9808
# Epoch 17/20
# 60000/60000 [==============================] - 6s 101us/step - loss: 0.0158 - acc: 0.9958 - val_loss: 0.0681 - val_acc: 0.9796
# Epoch 18/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0135 - acc: 0.9964 - val_loss: 0.0696 - val_acc: 0.9810
# Epoch 19/20
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.0115 - acc: 0.9972 - val_loss: 0.0769 - val_acc: 0.9797
# Epoch 20/20
# 60000/60000 [==============================] - 4s 66us/step - loss: 0.0098 - acc: 0.9975 - val_loss: 0.0740 - val_acc: 0.9806

# %% [markdown]
# Evaluate

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.07155236485830974
# Test accuracy: 0.9807

# %% [markdown]
# We can do better!
#
# bigger network + use RELU
# also dropout? or maybe in next chapter

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_dim=784))
model.add(Dense(512, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='RMSProp',
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=100,
          epochs=20,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.2051 - acc: 0.9365 - val_loss: 0.0932 - val_acc: 0.9717
# Epoch 2/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0807 - acc: 0.9745 - val_loss: 0.0782 - val_acc: 0.9754
# Epoch 3/20
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.0547 - acc: 0.9837 - val_loss: 0.0859 - val_acc: 0.9745
# Epoch 4/20
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.0399 - acc: 0.9878 - val_loss: 0.0825 - val_acc: 0.9793
# Epoch 5/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0303 - acc: 0.9910 - val_loss: 0.0960 - val_acc: 0.9774
# Epoch 6/20
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.0232 - acc: 0.9930 - val_loss: 0.0980 - val_acc: 0.9793
# Epoch 7/20
# 60000/60000 [==============================] - 4s 66us/step - loss: 0.0209 - acc: 0.9938 - val_loss: 0.0840 - val_acc: 0.9832
# Epoch 8/20
# 60000/60000 [==============================] - 4s 66us/step - loss: 0.0176 - acc: 0.9951 - val_loss: 0.1101 - val_acc: 0.9800
# Epoch 9/20
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.0161 - acc: 0.9951 - val_loss: 0.1293 - val_acc: 0.9795
# Epoch 10/20
# 60000/60000 [==============================] - 4s 66us/step - loss: 0.0132 - acc: 0.9963 - val_loss: 0.1239 - val_acc: 0.9796
# Epoch 11/20
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0122 - acc: 0.9968 - val_loss: 0.1331 - val_acc: 0.9790
# Epoch 12/20
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0110 - acc: 0.9972 - val_loss: 0.1261 - val_acc: 0.9806
# Epoch 13/20
# 60000/60000 [==============================] - 4s 71us/step - loss: 0.0104 - acc: 0.9971 - val_loss: 0.1343 - val_acc: 0.9805
# Epoch 14/20
# 60000/60000 [==============================] - 4s 71us/step - loss: 0.0080 - acc: 0.9979 - val_loss: 0.1189 - val_acc: 0.9838
# Epoch 15/20
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0095 - acc: 0.9977 - val_loss: 0.1303 - val_acc: 0.9828
# Epoch 16/20
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0080 - acc: 0.9979 - val_loss: 0.1262 - val_acc: 0.9838
# Epoch 17/20
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.0089 - acc: 0.9979 - val_loss: 0.1413 - val_acc: 0.9819
# Epoch 18/20
# 60000/60000 [==============================] - 4s 71us/step - loss: 0.0087 - acc: 0.9982 - val_loss: 0.1337 - val_acc: 0.9827
# Epoch 19/20
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.0071 - acc: 0.9982 - val_loss: 0.1330 - val_acc: 0.9823
# Epoch 20/20
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.0073 - acc: 0.9986 - val_loss: 0.1439 - val_acc: 0.9819

# %% [markdown]
# Current state of the art is:

# %% [markdown]
# Now let's try CIFAR.
